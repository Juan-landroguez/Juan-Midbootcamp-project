# %%
import pandas as pd
import numpy as np

# %%
EV = pd.read_excel('IFEMA.xlsx')

# %% [markdown]
# ##Cleaning

# %%
EV.columns=[e.lower().replace(' ', '_') for e in EV.columns] 
display(EV.head())
# Out:
#     año       mes  total_eventos  exposición  congresos_y_convenciones  \
# 0  1999   January            0.0         7.0                       0.0
# 1  1999  February            0.0         7.0                       0.0
# 2  1999     March            0.0         7.0                       0.0
# 3  1999     April            0.0         3.0                       0.0
# 4  1999       May            0.0         3.0                       0.0
#
#    conciertos_y_festivales  total_expositores  expositores_nacionales  \
# 0                      0.0        4843.666667             3440.666667
# 1                      0.0        4843.666667             3440.666667
# 2                      0.0        4843.666667             3440.666667
# 3                      0.0        1289.666667              898.333333
# 4                      0.0        1289.666667              898.333333
#
#    expositores_extranjeros  total_visitantes  total_visitantes_profesionales  \
# ...

# %%
EV['date'] = EV['mes'].astype(str) +"-"+ EV['año'].astype(str)

# %%
EV['total_eventos']=EV['exposición']+EV['congresos_y_convenciones'] +EV['conciertos_y_festivales']

# %%
EV=EV[['date','mes','año', 'total_eventos', 'exposición',
       'congresos_y_convenciones', 'conciertos_y_festivales',
       'total_expositores', 'expositores_nacionales',
       'expositores_extranjeros', 'total_visitantes',
       'total_visitantes_profesionales', 'visitantes_profesionales_nacionales',
       'visitantes_profesionales_extranjero', 'visitantes_particulares',
       'número_de_días_feriales']]
EV
# Out:
#                date        mes   año  total_eventos  exposición  \
# 0      January-1999    January  1999       7.000000    7.000000
# 1     February-1999   February  1999       7.000000    7.000000
# 2        March-1999      March  1999       7.000000    7.000000
# 3        April-1999      April  1999       3.000000    3.000000
# 4          May-1999        May  1999       3.000000    3.000000
# ..              ...        ...   ...            ...         ...
# 271     August-2021     August  2021      16.666667    5.666667
# 272  September-2021  September  2021      16.666667    5.666667
# 273    October-2021    October  2021      76.333333   15.333333
# 274   November-2021   November  2021      76.333333   15.333333
# 275   December-2021   December  2021      76.333333   15.333333
#
#      congresos_y_convenciones  conciertos_y_festivales  total_expositores  \
# 0                    0.000000                 0.000000        4843.666667
# ...

# %%
EV_cat = EV.select_dtypes(object)
EV_cat
# Out:
#                date        mes
# 0      January-1999    January
# 1     February-1999   February
# 2        March-1999      March
# 3        April-1999      April
# 4          May-1999        May
# ..              ...        ...
# 271     August-2021     August
# 272  September-2021  September
# 273    October-2021    October
# 274   November-2021   November
# 275   December-2021   December
#
# [276 rows x 2 columns]

# %%
from datetime import datetime
EV['date'] = pd.to_datetime(EV['date'])
EV['date'] = EV['date'].apply(lambda x: datetime.strftime(x,'%Y-%m-%d'))

EV['date'].head()
# Out:
# 0    1999-01-01
# 1    1999-02-01
# 2    1999-03-01
# 3    1999-04-01
# 4    1999-05-01
# Name: date, dtype: object

# %% [markdown]
# ##Saving on CSV

# %%
EV.to_csv('EV.csv', index=False)

# %%
import pymysql                        
from sqlalchemy import create_engine  
from getpass import getpass

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/Juan_Midbootcamp'
engine = create_engine(connection_string)

# %%
table_name = 'EV'
EV.to_sql(table_name, con=engine, if_exists='replace', index=False)
# Out:
# 276

# %% [markdown]
# ##Opening SQL file

# %%
TestingSQL = pd.read_sql_query('SELECT * FROM Juan_Midbootcamp.EV', engine)
TestingSQL
# Out:
#            date        mes   año  total_eventos  exposición  \
# 0    1999-01-01    January  1999       7.000000    7.000000
# 1    1999-02-01   February  1999       7.000000    7.000000
# 2    1999-03-01      March  1999       7.000000    7.000000
# 3    1999-04-01      April  1999       3.000000    3.000000
# 4    1999-05-01        May  1999       3.000000    3.000000
# ..          ...        ...   ...            ...         ...
# 271  2021-08-01     August  2021      16.666667    5.666667
# 272  2021-09-01  September  2021      16.666667    5.666667
# 273  2021-10-01    October  2021      76.333333   15.333333
# 274  2021-11-01   November  2021      76.333333   15.333333
# 275  2021-12-01   December  2021      76.333333   15.333333
#
#      congresos_y_convenciones  conciertos_y_festivales  total_expositores  \
# 0                    0.000000                 0.000000        4843.666667
# 1                    0.000000                 0.000000        4843.666667
# ...
