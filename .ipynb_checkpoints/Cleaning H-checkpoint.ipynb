# %%
import pandas as pd
import numpy as np

# %%
H1 = pd.read_excel('H.Demanda hotelera en Madrid por Mes.xlsx')
H2 = pd.read_excel('H.Oferta hotelera en Madrid por Mes.xlsx')
H3 = pd.read_excel('H.Pernoctaciones en Madrid por País de residencia.xlsx')
H4 = pd.read_excel('H.Pernoctaciones viajeros (residentes en España) x CA y Mes.xlsx')
H5 = pd.read_excel('H.Viajeros (residentes en España) en Madrid x procedencia y Mes.xlsx')
H6 = pd.read_excel('H.Viajeros en la ciudad de Madrid por País de residencia.xlsx')

# %%
H1.columns=[e.lower().replace(' ', '_') for e in H1.columns] 
display(H1.head())
H2.columns=[e.lower().replace(' ', '_') for e in H2.columns] 
display(H2.head())
H3.columns=[e.lower().replace(' ', '_') for e in H3.columns] 
display(H3.head())
H4.columns=[e.lower().replace(' ', '_') for e in H4.columns] 
display(H4.head())
H5.columns=[e.lower().replace(' ', '_') for e in H5.columns] 
display(H5.head())
H6.columns=[e.lower().replace(' ', '_') for e in H6.columns] 
display(H6.head())
# Out:
#     año       mes  h_total_travelers  h_total_nigts_stays  \
# 0  1999   January           315037.0             740403.0
# 1  1999  February           323361.0             742751.0
# 2  1999     March           405495.0             928374.0
# 3  1999     April           423969.0             966568.0
# 4  1999       May           445441.0             973432.0
#
#    h_average_stay_(days)
# 0                   2.35
# 1                   2.30
# 2                   2.29
# 3                   2.28
# 4                   2.19
#     año       mes  #_hotels  h_capacity  h_occupancy_per_rooms  \
# 0  1999   January    1048.0     51497.0                  59.10
# 1  1999  February    1044.0     52985.0                  64.90
# 2  1999     March    1038.0     53643.0                  69.24
# 3  1999     April    1031.0     54641.0                  71.63
# 4  1999       May    1028.0     54265.0                  73.01
#
# ...

# %%
display(H1.shape)
display(H1.isnull().sum())
display(H1.dtypes)
# Out:
# (300, 5)
# año                      0
# mes                      0
# h_total_travelers        0
# h_total_nigts_stays      0
# h_average_stay_(days)    0
# dtype: int64
# año                        int64
# mes                       object
# h_total_travelers        float64
# h_total_nigts_stays      float64
# h_average_stay_(days)    float64
# dtype: object

# %%
H1['date'] = H1['mes'].astype(str) +"-"+ H1['año'].astype(str)
H2['date'] = H2['mes'].astype(str) +"-"+ H2['año'].astype(str)
H3['date'] = H3['mes'].astype(str) +"-"+ H3['año'].astype(str)
H4['date'] = H4['mes'].astype(str) +"-"+ H4['año'].astype(str)
H5['date'] = H5['mes'].astype(str) +"-"+ H5['año'].astype(str)
H6['date'] = H6['mes'].astype(str) +"-"+ H6['año'].astype(str)

# %%
H1_2=H1.drop(['año','mes','date'],axis=1)
H1_2
# Out:
#      h_total_travelers  h_total_nigts_stays  h_average_stay_(days)
# 0             315037.0             740403.0                   2.35
# 1             323361.0             742751.0                   2.30
# 2             405495.0             928374.0                   2.29
# 3             423969.0             966568.0                   2.28
# 4             445441.0             973432.0                   2.19
# ..                 ...                  ...                    ...
# 295                0.0                  0.0                   0.00
# 296                0.0                  0.0                   0.00
# 297                0.0                  0.0                   0.00
# 298                0.0                  0.0                   0.00
# 299                0.0                  0.0                   0.00
#
# [300 rows x 3 columns]

# %%
H2_c=list(H2.columns)
H2_c
# Out:
# ['año',
#  'mes',
#  '#_hotels',
#  'h_capacity',
#  'h_occupancy_per_rooms',
#  'h_occupancy_per_capacity',
#  'h_occupancy_per_capacity_during_weekends',
#  'h_staff',
#  'date']

# %%
H2_2= H2[['date','#_hotels',
 'h_capacity',
 'h_occupancy_per_rooms',
 'h_occupancy_per_capacity',
 'h_occupancy_per_capacity_during_weekends',
 'h_staff']]

# %%
H_totals = pd.concat([H2_2, H1_2], axis = 1)
H_totals
# Out:
#                date  #_hotels  h_capacity  h_occupancy_per_rooms  \
# 0      January-1999    1048.0     51497.0                  59.10
# 1     February-1999    1044.0     52985.0                  64.90
# 2        March-1999    1038.0     53643.0                  69.24
# 3        April-1999    1031.0     54641.0                  71.63
# 4          May-1999    1028.0     54265.0                  73.01
# ..              ...       ...         ...                    ...
# 295     August-2023       0.0         0.0                   0.00
# 296  September-2023       0.0         0.0                   0.00
# 297    October-2023       0.0         0.0                   0.00
# 298   November-2023       0.0         0.0                   0.00
# 299   December-2023       0.0         0.0                   0.00
#
#      h_occupancy_per_capacity  h_occupancy_per_capacity_during_weekends  \
# 0                       46.25                                     52.26
# ...

# %%
H3.columns
# Out:
# Index(['año', 'mes', 'h_total_nights_stays_foreigns',
#        'h_nights_stays_alemania', 'h_nights_stays_austria',
#        'h_nights_stays_bélgica', 'h_nights_stays_dinamarca',
#        'h_nights_stays_finlandia', 'h_nights_stays_francia',
#        'h_nights_stays_grecia', 'h_nights_stays_países_bajos',
#        'h_nights_stays_irlanda', 'h_nights_stays_italia',
#        'h_nights_stays_luxemburgo', 'h_nights_stays_portugal',
#        'h_nights_stays_reino_unido', 'h_nights_stays_suecia',
#        'h_nights_stays_eslovaquia', 'h_nights_stays_hungría',
#        'h_nights_stays_islandia', 'h_nights_stays_noruega',
#        'h_nights_stays_polonia', 'h_nights_stays_república_checa',
#        'h_nights_stays_suiza_y_liechtenstein', 'h_nights_stays_turquía',
#        'h_nights_stays_rusia', 'h_nights_stays_otros_países_de_europa',
#        'h_nights_stays_africa', 'h_nights_stays_estados_unidos',
#        'h_nights_stays_argentina', 'h_nights_stays_brasil',
# ...

# %%
H3_2= H3[['date', 'mes','año','h_total_nights_stays_foreigns',
       'h_nights_stays_alemania', 'h_nights_stays_austria',
       'h_nights_stays_bélgica', 'h_nights_stays_dinamarca',
       'h_nights_stays_finlandia', 'h_nights_stays_francia',
       'h_nights_stays_grecia', 'h_nights_stays_países_bajos',
       'h_nights_stays_irlanda', 'h_nights_stays_italia',
       'h_nights_stays_luxemburgo', 'h_nights_stays_portugal',
       'h_nights_stays_reino_unido', 'h_nights_stays_suecia',
       'h_nights_stays_eslovaquia', 'h_nights_stays_hungría',
       'h_nights_stays_islandia', 'h_nights_stays_noruega',
       'h_nights_stays_polonia', 'h_nights_stays_república_checa',
       'h_nights_stays_suiza_y_liechtenstein', 'h_nights_stays_turquía',
       'h_nights_stays_rusia', 'h_nights_stays_otros_países_de_europa',
       'h_nights_stays_africa', 'h_nights_stays_estados_unidos',
       'h_nights_stays_argentina', 'h_nights_stays_brasil',
       'h_nights_stays_canadá', 'h_nights_stays_méxico',
       'h_nights_stays_venezuela',
       'h_nights_stays_resto_de_américa_central_y_sur', 'h_nights_stays_japón',
       'h_nights_stays_resto_de_asia', 'h_nights_stays_australia',
       'h_nights_stays_nueva_zelanda', 'h_nights_stays_otro_país']]

# %%
H6_2=H6.drop(['mes','año','date'],axis=1)
H_countries=pd.concat([H3_2, H6_2], axis = 1)
H_countries
# Out:
#                date        mes   año h_total_nights_stays_foreigns  \
# 0      January-1999    January  1999                        314165
# 1     February-1999   February  1999                        322076
# 2        March-1999      March  1999                        446227
# 3        April-1999      April  1999                        520483
# 4          May-1999        May  1999                        516197
# ..              ...        ...   ...                           ...
# 295     August-2023     August  2023                             0
# 296  September-2023  September  2023                             0
# 297    October-2023    October  2023                             0
# 298   November-2023   November  2023                             0
# 299   December-2023   December  2023                             0
#
#      h_nights_stays_alemania  h_nights_stays_austria  h_nights_stays_bélgica  \
# 0                      14519                    2373                  3890.0
# ...

# %%
H4.columns
# Out:
# Index(['año', 'mes', 'h_total_nights_stays_spanishs',
#        'h_nights_stays_andalucía', 'h_nights_stays_aragón',
#        'h_nights_stays_principado_de_asturias', 'h_nights_stays_illes_balears',
#        'h_nights_stays_canarias', 'h_nights_stays_cantabria',
#        'h_nights_stays_castilla_y_león', 'h_nights_stays_castilla-la_mancha',
#        'h_nights_stays_cataluña', 'h_nights_stays_comunitat_valenciana',
#        'h_nights_stays_extremadura', 'h_nights_stays_galicia',
#        'h_nights_stays_comunidad_de_madrid', 'h_nights_stays_región_de_murcia',
#        'h_nights_stays_comunidad_foral_de_navarra',
#        'h_nights_stays_país_vasco', 'h_nights_stays_la_rioja',
#        'h_nights_stays_ceuta_y_melilla', 'date'],
#       dtype='object')

# %%
H5.columns
# Out:
# Index(['año', 'mes', 'h_total_travelers_spain', 'h_travelers_andalucía',
#        'h_travelers_aragón', 'h_travelers_principado_de_asturias',
#        'h_travelers_illes_balears', 'h_travelers_canarias',
#        'h_travelers_cantabria', 'h_travelers_castilla-león',
#        'h_travelers_castilla-la_mancha', 'h_travelers_cataluña',
#        'h_travelers_comunitat_valenciana', 'h_travelers_extremadura',
#        'h_travelers_galicia', 'h_travelers_comunidad_de_madrid',
#        'h_travelers_región_de_murcia',
#        'h_travelers_comunidad_foral_de_navarra', 'h_travelers_país_vasco',
#        'h_travelers_la_rioja', 'h_travelers_ceuta_y_melilla', 'date'],
#       dtype='object')

# %%
H4_2= H4[['date','h_total_nights_stays_spanishs',
       'h_nights_stays_andalucía', 'h_nights_stays_aragón',
       'h_nights_stays_principado_de_asturias', 'h_nights_stays_illes_balears',
       'h_nights_stays_canarias', 'h_nights_stays_cantabria',
       'h_nights_stays_castilla_y_león', 'h_nights_stays_castilla-la_mancha',
       'h_nights_stays_cataluña', 'h_nights_stays_comunitat_valenciana',
       'h_nights_stays_extremadura', 'h_nights_stays_galicia',
       'h_nights_stays_comunidad_de_madrid', 'h_nights_stays_región_de_murcia',
       'h_nights_stays_comunidad_foral_de_navarra',
       'h_nights_stays_país_vasco', 'h_nights_stays_la_rioja',
       'h_nights_stays_ceuta_y_melilla']]

# %%
H5_2=H5.drop(['mes','año','date'],axis=1)

# %%
H_nationals=pd.concat([H4_2, H5_2], axis = 1)
H_nationals
# Out:
#                date  h_total_nights_stays_spanishs  h_nights_stays_andalucía  \
# 0      January-2004                         417664                     59030
# 1     February-2004                         466626                     69153
# 2        March-2004                         458080                     65849
# 3        April-2004                         444607                     59694
# 4          May-2004                         499710                     72457
# ..              ...                            ...                       ...
# 235     August-2023                              0                         0
# 236  September-2023                              0                         0
# 237    October-2023                              0                         0
# 238   November-2023                              0                         0
# 239   December-2023                              0                         0
#
# ...

# %%
H_nationals.shape
# Out:
# (240, 39)

# %%
H_countries.shape
# Out:
# (300, 79)

# %%
H_totals.shape
# Out:
# (300, 10)

# %%
H_origin = pd.merge(left = H_countries,
                                 right = H_nationals,
                                 how = 'left', 
                                 left_on = "date", 
                                 right_on= "date")

# %%
H_origin_c=list(H_origin.columns)

# %%
H_origin_c
# Out:
# ['date',
#  'mes',
#  'año',
#  'h_total_nights_stays_foreigns',
#  'h_nights_stays_alemania',
#  'h_nights_stays_austria',
#  'h_nights_stays_bélgica',
#  'h_nights_stays_dinamarca',
#  'h_nights_stays_finlandia',
#  'h_nights_stays_francia',
#  'h_nights_stays_grecia',
#  'h_nights_stays_países_bajos',
#  'h_nights_stays_irlanda',
#  'h_nights_stays_italia',
#  'h_nights_stays_luxemburgo',
#  'h_nights_stays_portugal',
#  'h_nights_stays_reino_unido',
#  'h_nights_stays_suecia',
#  'h_nights_stays_eslovaquia',
#  'h_nights_stays_hungría',
#  'h_nights_stays_islandia',
#  'h_nights_stays_noruega',
#  'h_nights_stays_polonia',
#  'h_nights_stays_república_checa',
#  'h_nights_stays_suiza_y_liechtenstein',
#  'h_nights_stays_turquía',
#  'h_nights_stays_rusia',
#  'h_nights_stays_otros_países_de_europa',
#  'h_nights_stays_africa',
#  'h_nights_stays_estados_unidos',
#  'h_nights_stays_argentina',
#  'h_nights_stays_brasil',
#  'h_nights_stays_canadá',
#  'h_nights_stays_méxico',
# ...

# %%
Hotels_df= pd.merge(left = H_totals,
                                 right = H_origin,
                                 how = 'left', 
                                 left_on = "date", 
                                 right_on= "date")
Hotels_df
# Out:
#                date  #_hotels  h_capacity  h_occupancy_per_rooms  \
# 0      January-1999    1048.0     51497.0                  59.10
# 1     February-1999    1044.0     52985.0                  64.90
# 2        March-1999    1038.0     53643.0                  69.24
# 3        April-1999    1031.0     54641.0                  71.63
# 4          May-1999    1028.0     54265.0                  73.01
# ..              ...       ...         ...                    ...
# 295     August-2023       0.0         0.0                   0.00
# 296  September-2023       0.0         0.0                   0.00
# 297    October-2023       0.0         0.0                   0.00
# 298   November-2023       0.0         0.0                   0.00
# 299   December-2023       0.0         0.0                   0.00
#
#      h_occupancy_per_capacity  h_occupancy_per_capacity_during_weekends  \
# 0                       46.25                                     52.26
# ...

# %%
Hotels_df_c=list(Hotels_df.columns)
Hotels_df_c
# Out:
# ['date',
#  '#_hotels',
#  'h_capacity',
#  'h_occupancy_per_rooms',
#  'h_occupancy_per_capacity',
#  'h_occupancy_per_capacity_during_weekends',
#  'h_staff',
#  'h_total_travelers',
#  'h_total_nigts_stays',
#  'h_average_stay_(days)',
#  'mes',
#  'año',
#  'h_total_nights_stays_foreigns',
#  'h_nights_stays_alemania',
#  'h_nights_stays_austria',
#  'h_nights_stays_bélgica',
#  'h_nights_stays_dinamarca',
#  'h_nights_stays_finlandia',
#  'h_nights_stays_francia',
#  'h_nights_stays_grecia',
#  'h_nights_stays_países_bajos',
#  'h_nights_stays_irlanda',
#  'h_nights_stays_italia',
#  'h_nights_stays_luxemburgo',
#  'h_nights_stays_portugal',
#  'h_nights_stays_reino_unido',
#  'h_nights_stays_suecia',
#  'h_nights_stays_eslovaquia',
#  'h_nights_stays_hungría',
#  'h_nights_stays_islandia',
#  'h_nights_stays_noruega',
#  'h_nights_stays_polonia',
#  'h_nights_stays_república_checa',
#  'h_nights_stays_suiza_y_liechtenstein',
#  'h_nights_stays_turquía',
# ...

# %%
Hotels_df= Hotels_df[['date','mes',
 'año',
 '#_hotels',
 'h_capacity',
 'h_occupancy_per_rooms',
 'h_occupancy_per_capacity',
 'h_occupancy_per_capacity_during_weekends',
 'h_staff',
 'h_total_travelers',
 'h_total_nigts_stays',
 'h_average_stay_(days)',
 'h_total_nights_stays_foreigns',
 'h_nights_stays_alemania',
 'h_nights_stays_austria',
 'h_nights_stays_bélgica',
 'h_nights_stays_dinamarca',
 'h_nights_stays_finlandia',
 'h_nights_stays_francia',
 'h_nights_stays_grecia',
 'h_nights_stays_países_bajos',
 'h_nights_stays_irlanda',
 'h_nights_stays_italia',
 'h_nights_stays_luxemburgo',
 'h_nights_stays_portugal',
 'h_nights_stays_reino_unido',
 'h_nights_stays_suecia',
 'h_nights_stays_eslovaquia',
 'h_nights_stays_hungría',
 'h_nights_stays_islandia',
 'h_nights_stays_noruega',
 'h_nights_stays_polonia',
 'h_nights_stays_república_checa',
 'h_nights_stays_suiza_y_liechtenstein',
 'h_nights_stays_turquía',
 'h_nights_stays_rusia',
 'h_nights_stays_otros_países_de_europa',
 'h_nights_stays_africa',
 'h_nights_stays_estados_unidos',
 'h_nights_stays_argentina',
 'h_nights_stays_brasil',
 'h_nights_stays_canadá',
 'h_nights_stays_méxico',
 'h_nights_stays_venezuela',
 'h_nights_stays_resto_de_américa_central_y_sur',
 'h_nights_stays_japón',
 'h_nights_stays_resto_de_asia',
 'h_nights_stays_australia',
 'h_nights_stays_nueva_zelanda',
 'h_nights_stays_otro_país',
 'h_total_foreign_travelers',
 'h_travelers_alemania',
 'h_travelers_austria',
 'h_travelers_bélgica',
 'h_travelers_dinamarca',
 'h_travelers_finlandia',
 'h_travelers_francia',
 'h_travelers_grecia',
 'h_travelers_países_bajos',
 'h_travelers_irlanda',
 'h_travelers_italia',
 'h_travelers_luxemburgo',
 'h_travelers_portugal',
 'h_travelers_reino_unido',
 'h_travelers_suecia',
 'h_travelers_eslovaquia',
 'h_travelers_hungría',
 'h_travelers_islandia',
 'h_travelers_noruega',
 'h_travelers_polonia',
 'h_travelers_república_checa',
 'h_travelers_suiza_y_liechtenstein',
 'h_travelers_turquía',
 'h_travelers_rusia',
 'h_travelers_otros_países_de_europa',
 'h_travelers_africa',
 'h_travelers_argentina',
 'h_travelers_brasil',
 'h_travelers_canadá',
 'h_travelers_estados_unidos',
 'h_travelers_méjico',
 'h_travelers_venezuela',
 'h_travelers_resto_de_américa',
 'h_travelers_japón',
 'h_travelers_resto_de_asia',
 'h_travelers_australia',
 'h_travelers_nueva_zelanda',
 'h_travelers_otro_país',
 'h_total_nights_stays_spanishs',
 'h_nights_stays_andalucía',
 'h_nights_stays_aragón',
 'h_nights_stays_principado_de_asturias',
 'h_nights_stays_illes_balears',
 'h_nights_stays_canarias',
 'h_nights_stays_cantabria',
 'h_nights_stays_castilla_y_león',
 'h_nights_stays_castilla-la_mancha',
 'h_nights_stays_cataluña',
 'h_nights_stays_comunitat_valenciana',
 'h_nights_stays_extremadura',
 'h_nights_stays_galicia',
 'h_nights_stays_comunidad_de_madrid',
 'h_nights_stays_región_de_murcia',
 'h_nights_stays_comunidad_foral_de_navarra',
 'h_nights_stays_país_vasco',
 'h_nights_stays_la_rioja',
 'h_nights_stays_ceuta_y_melilla',
 'h_total_travelers_spain',
 'h_travelers_andalucía',
 'h_travelers_aragón',
 'h_travelers_principado_de_asturias',
 'h_travelers_illes_balears',
 'h_travelers_canarias',
 'h_travelers_cantabria',
 'h_travelers_castilla-león',
 'h_travelers_castilla-la_mancha',
 'h_travelers_cataluña',
 'h_travelers_comunitat_valenciana',
 'h_travelers_extremadura',
 'h_travelers_galicia',
 'h_travelers_comunidad_de_madrid',
 'h_travelers_región_de_murcia',
 'h_travelers_comunidad_foral_de_navarra',
 'h_travelers_país_vasco',
 'h_travelers_la_rioja',
 'h_travelers_ceuta_y_melilla']]

# %%
Hotels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 0 to 299
# Columns: 126 entries, date to h_travelers_ceuta_y_melilla
# dtypes: float64(51), int64(72), object(3)
# memory usage: 297.7+ KB

# %%
from datetime import datetime
Hotels_df['date'] = pd.to_datetime(Hotels_df['date'])
Hotels_df['date'] = Hotels_df['date'].apply(lambda x: datetime.strftime(x, '%Y-%m-%d'))

Hotels_df['date'].head()
# Out:
# 0    1999-01-01
# 1    1999-02-01
# 2    1999-03-01
# 3    1999-04-01
# 4    1999-05-01
# Name: date, dtype: object

# %%
Hotels_df.to_csv('Hotels_df.csv', index=False)

# %%
Hotels_df

# %%
# import pymysql                        # for getting data from a SQL database
# from sqlalchemy import create_engine  # for establishing the connection and authentication

# from getpass import getpass  # To get the password without showing the input

# %%
# password = getpass()

# %%
# connection_string = 'mysql+pymysql://root:'+password+'@localhost/Juan_Midbootcamp'
# engine = create_engine(connection_string)

# %%
# table_name = 'Hotels'
# Hotels_df.to_sql(table_name, con=engine, if_exists='replace', index=False)

# %%
# from datetime import datetime
# Hotels_df['date'] = pd.to_datetime(Hotels_df['date'])
# Hotels_df['date'] = Hotels_df['date'].apply(lambda x: datetime.strftime(x, '%Y-%m-%d'))

# Hotels_df['date'].head()
